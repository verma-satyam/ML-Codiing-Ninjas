# %% [markdown]
# <a href="https://colab.research.google.com/github/verma-satyam/ML-Coding-Ninjas/blob/main/15.%20NN/3_ForwardPropagation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
X = np.array([[0,0],[0,1],[1,0],[1,1]])
Y = np.array([[0,0,0,1]]).T
X.shape,Y.shape
# Out:
# ((4, 2), (4, 1))

# %%
def sigmoid(z):
  return 1/(1 + np.exp(-z))

# %%
wh = 2 * np.random.random((2,2)) - 1 
wo = 2 * np.random.random((2,1)) - 1 
bh = 2 * np.random.random((1,2)) - 1 
bo = 2 * np.random.random((1,1)) - 1

# %%
inputLayer = X
hiddenLayer = sigmoid(np.dot(inputLayer,wh) + bh)
outputLayer = sigmoid(np.dot(hiddenLayer,wo) + bo)
# we did not do any learning too. Just outputed with the inital random weights.
outputLayer
# Out:
# array([[0.56728772],
#        [0.54002774],
#        [0.58526875],
#        [0.55247624]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - W11 - wts of x1 and h1.
# - W21 - wts of x2 and h1.
# - W12 - wts of x1 and h2.
# - W22 - wts of x2 and h2.
